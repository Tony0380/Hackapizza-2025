# %% [markdown]
# # Motore di ricerca
#
# - RAG

# %%
from src.Generation import rag_pipeline

pquery = "C'è un codice galaticco per il cibo? Se si di cosa parla?"

#response = search("../../HackapizzaDataset", pquery, 20)
response = rag_pipeline("HackapizzaDataset", pquery,5)

print("🔹 RISPOSTA:")
print(response.content)
# Out:
# 🌍 Caricando: HackapizzaDataset/Blogpost/blog_sapore_del_dune.html
# 🌍 Caricando: HackapizzaDataset/Blogpost/blog_etere_del_gusto.html
# 📄 Caricando: HackapizzaDataset/Menu/Stelle Astrofisiche.pdf
# 📄 Caricando: HackapizzaDataset/Menu/Ristorante delle Dune Stellari.pdf
# 📄 Caricando: HackapizzaDataset/Menu/L Eco dei Sapori.pdf
# 📄 Caricando: HackapizzaDataset/Menu/L Essenza delle Dune.pdf
# 📄 Caricando: HackapizzaDataset/Menu/L Essenza del Multiverso su Pandora.pdf
# 📄 Caricando: HackapizzaDataset/Menu/Armonia Universale.pdf
# 📄 Caricando: HackapizzaDataset/Menu/Il Firmamento.pdf
# 📄 Caricando: HackapizzaDataset/Menu/Universo Gastronomico di Namecc.pdf
# 📄 Caricando: HackapizzaDataset/Menu/L Essenza di Asgard.pdf
# 📄 Caricando: HackapizzaDataset/Menu/Tutti a TARSvola.pdf
# 📄 Caricando: HackapizzaDataset/Menu/L Etere del Gusto.pdf
# 📄 Caricando: HackapizzaDataset/Menu/L Universo in Cucina.pdf
# 📄 Caricando: HackapizzaDataset/Menu/L Architetto dell Universo.pdf
# ...
